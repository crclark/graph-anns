# %%
import pandas as pd

# %%
df = pd.read_csv('search_stats.csv')

# %%
df.describe()
# Out:
#        nearest_neighbor_distance  num_distance_computations  \
# count               10000.000000               10000.000000
# mean                76558.829500                 307.852800
# std                 34313.828894                  98.919989
# min                  1429.000000                  89.000000
# 25%                 51900.250000                 240.000000
# 50%                 76887.000000                 298.000000
# 75%                100435.250000                 363.000000
# max                235586.000000                1231.000000
#
#        distance_from_nearest_starting_point  \
# count                          10000.000000
# mean                         -130196.756000
# std                            45026.655543
# min                          -298395.000000
# 25%                          -158932.250000
# 50%                          -127864.000000
# 75%                           -98396.250000
# max                            21528.000000
#
# ...

# %%
df.found_closest
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995     True
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Name: found_closest, Length: 10000, dtype: bool
